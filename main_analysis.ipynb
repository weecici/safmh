# %%
import os
import kagglehub
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import wordcloud

# %% [markdown]
# # 1. Dataset Preparation

# %%
path = kagglehub.dataset_download(
    "suchintikasarkar/sentiment-analysis-for-mental-health"
)
print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.13), please consider upgrading to the latest version (0.4.0).
# Path to dataset files: /home/cici/.cache/kagglehub/datasets/suchintikasarkar/sentiment-analysis-for-mental-health/versions/1

# %%
df = pd.read_csv(path + "/Combined Data.csv")
df.head()
# Out:
#    Unnamed: 0                                          statement   status
# 0           0                                         oh my gosh  Anxiety
# 1           1  trouble sleeping, confused mind, restless hear...  Anxiety
# 2           2  All wrong, back off dear, forward doubt. Stay ...  Anxiety
# 3           3  I've shifted my focus to something else but I'...  Anxiety
# 4           4  I'm restless and restless, it's been a month n...  Anxiety

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53043 entries, 0 to 53042
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53043 non-null  int64
#  1   statement   52681 non-null  object
#  2   status      53043 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.2+ MB

# %%
df = df.dropna()

# %%
dups = df.duplicated(subset=["statement"]).sum()
print(f"Total duplicate statements in entire dataset: {dups}")

dups_per_status = (
    df[df.duplicated(subset=["statement"], keep=False)].groupby("status").size()
)
print("\nDuplicates found per status:")
print(dups_per_status)

df = df.drop_duplicates(subset=["statement"], keep="first").copy()
# Out:
# Total duplicate statements in entire dataset: 1608
#
# Duplicates found per status:
# status
# Anxiety                 433
# Bipolar                 552
# Depression              601
# Normal                  463
# Personality disorder    362
# Stress                  574
# Suicidal                 26
# dtype: int64

# %% [markdown]
# # 2. Dataset Analysis

# %%
drop = ["Anxiety", "Stress", "Bipolar", "Personality disorder"]

df = df[~df["status"].isin(drop)].copy()
df = df.reset_index(drop=True)

# %% [markdown]
# ## 2.2. Manual Analysis for Some Samples

# %%
SEED = 42

# %%
def subsample(df: pd.DataFrame, n: int = 20, seed: int = SEED) -> pd.DataFrame:
    return df.groupby("status").sample(n=n, random_state=seed).reset_index(drop=True)

# %%
subsampled_df = subsample(df).drop(columns=["Unnamed: 0"])
subsampled_df.head()
# Out:
#                                            statement      status
# 0  i wonder what misery awaits me in the msq toda...  Depression
# 1  I don't feel great I'm 14 and I just wanna die...  Depression
# 2  My depression comes and goes these past days h...  Depression
# 3  It seems like the more I get in touch with peo...  Depression
# 4  ok so i have been anxious for about year now i...  Depression

# %%
subsampled_df["status"].value_counts()
# Out:
# status
# Depression    20
# Normal        20
# Suicidal      20
# Name: count, dtype: int64

# %%
subsampled_df.to_csv("data/subsampled.csv", index=False)

# %%
shuffled_df = subsampled_df.sample(frac=1, random_state=SEED).reset_index(drop=True)
shuffled_df.head()
# Out:
#                                            statement      status
# 0  i wonder what misery awaits me in the msq toda...  Depression
# 1  Can you share what your indicators are that an...  Depression
# 2                                      Direct 2 dong      Normal
# 3  Fucking hell what is wrong with me, I am so fu...    Suicidal
# 4  I have my exams going onn. One over 4 left for...  Depression

# %%
manual_df = pd.read_csv("data/manual_analysis.csv")
manual_df
# Out:
#                                             statement  \
# 0   i wonder what misery awaits me in the msq toda...
# 1   Can you share what your indicators are that an...
# 2                                       Direct 2 dong
# 3   Fucking hell what is wrong with me, I am so fu...
# 4   I have my exams going onn. One over 4 left for...
# 5   I do not know how people work 30+ hours per we...
# 6     But it's good that the A&W Ipoh Parade is open.
# 7   i cant live in this world ok its too much its ...
# 8   I have had a crush on this girl for a very lon...
# 9   NSFWI have been depressed since a child. I wat...
# 10  A week ago I was fine. Now all my friends hate...
# 11  I am the biggest fucking bitch. I am an angry ...
# 12  yo jimo i cant talk on aim anymore it glitchin...
# 13  It seems like the more I get in touch with peo...
# 14  I had a belt tight around my neck twice last n...
# 15  I cannot sleep, shaking and my mind feels like...
# 16  i ve been having this thought that depression ...
# 17  i (15f) have been depressed for like 2 months ...
# 18  Hey, all! English is not my native language so...
# 19  ok so i have been anxious for about year now i...
# 20  Just curious about if this causes any pain. I ...
# 21  I do not have anything to say, I just feel emp...
# 22  ha realized that twitter is getting more atten...
# 23  I cannot live like this anymore. Random painfu...
# 24                                  Make it invisible
# 25  I know it may sound stupid but I feel so unbea...
# 26  if I am dead, i cannot feel relief or contentm...
# 27  Do you find this normal? They have a good rela...
# 28  in recent week i ve been starting to learn how...
# 29  Have you ever been amazed by your own dream sk...
# 30  So I miss my high school friends already hadee...
# 31  I have been nearly depressed for more than 6 y...
# 32              so, they do a good job for the money.
# 33  Two of the worst things that ever happened to ...
# 34  Idk if this is the right place to rant but I a...
# 35     beththepq your blog won t let me comment again
# 36  i am going to kill myself tonight i am a lesbi...
# 37  Honestly I do not know where to begin. I am sh...
# 38  already know again coming a month maybe not re...
# 39  I turned 15 shortly after meeting him. He star...
# 40  1. I am going to be working at a fucking pizza...
# 41  I don't feel great I'm 14 and I just wanna die...
# 42  same as ever, by mail. all it costs me is a 42...
# 43  My depression comes and goes these past days h...
# 44  I am 16. I failed 10th grade because of strugg...
# 45      just burnt my finger on a hot cup of tea ouch
# 46  reeked of alcohol at the dentist this morning ...
# 47            QLDHDKSH VERY PROUD OF DREAM PEN CRYING
# 48  Am free to talk if you want to get something o...
# 49  So yes, I have severe depression. I am in ther...
# 50  rcompo rachel hang outage is neccessary i wa g...
# 51  just the same old stuff going on for year i fe...
# 52  I know how. there is no 100% success rate but ...
# 53  The dog's turn is already on the train, he's a...
# 54  I recently saw a therapist for the first time ...
# 55  I do not necessarily fear death, but at the sa...
# 56  it s not easy being useless i am honestly just...
# 57                 you can travel all over the world.
# 58  So I know suicidal feelings are probably the r...
# 59  djalizay i really don t think people choose to...
#
#               theme/topic (subcode) manual_label (code)  \
# 0                                 1          Depression
# 1                                 1          Depression
# 2                      Information?              Normal
# 3                Self-directed rage            Suicidal
# 4                                 1          Depression
# 5                       Work phobia          Depression
# 6                                 1              Normal
# 7                                 1            Suicidal
# 8                                 1          Depression
# 9   Past trauma & Suicidal Ideation            Suicidal
# 10                                1            Suicidal
# 11                                1            Suicidal
# 12                      Information              Normal
# 13                                1          Depression
# 14                                1            Suicidal
# 15                                1            Suicidal
# 16                                1          Depression
# 17                                1          Depression
# 18                                1            Suicidal
# 19                                1          Depression
# 20                                1            Suicidal
# 21                                1            Suicidal
# 22                                1              Normal
# 23                                1            Suicidal
# 24                                1              Normal
# 25                                1          Depression
# 26                                1            Suicidal
# 27                                1              Normal
# 28                                1          Depression
# 29                                1              Normal
# 30                                1              Normal
# 31                                1            Suicidal
# 32                                1              Normal
# 33                                1            Suicidal
# 34                                1          Depression
# 35                                1              Normal
# 36                                1            Suicidal
# 37                                1          Depression
# 38                                1              Normal
# 39                                1          Depression
# 40                                1            Suicidal
# 41                                1            Suicidal
# 42                                1              Normal
# 43                                1          Depression
# 44                                1          Depression
# 45                                1              Normal
# 46                                1              Normal
# 47                                1              Normal
# 48                                1              Normal
# 49                                1          Depression
# 50                                1              Normal
# 51                                1          Depression
# 52                                1          Depression
# 53                                1              Normal
# 54                                1          Depression
# 55                                1            Suicidal
# 56                                1            Suicidal
# 57                                1              Normal
# 58                                1            Suicidal
# 59                                1              Normal
#
#                                      evidence_phrases  \
# 0                     "misery","depression","despair"
# 1                      "episode","depressive episode"
# 2                                                 NaN
# 3   "Fucking hell what is wrong with me","I am so ...
# 4   "have not studied anything"," iv wasted a lot ...
# 5   "my phobia of working has only gotten worse","...
# 6                                                 NaN
# 7   "i cant live in this world","i cant handle it ...
# 8   "confused me","she literally started ignoring ...
# 9   "i have cried because i am tired of living and...
# 10  "If the virus does not kill me then I sure as ...
# 11  "the only thing I can do is cut where no one c...
# 12                                                NaN
# 13  "Do I have a social skills disorder or somethi...
# 14  "I had a belt tight around my neck twice last ...
# 15  "I am shakingeverything around me feels like i...
# 16  "depression", "the harder you try to push away...
# 17  "have been depressed for like 2 months now", "...
# 18  "shows hard suicidal thoughts", "talking that ...
# 19  "anxious for about year now", "got way out of ...
# 20  "curious about if this causes any pain", "alre...
# 21  "I do not want to deal with me anymore", "The ...
# 22                                                NaN
# 23  "I cannot live like this anymore", "Random pai...
# 24                                                NaN
# 25  "feel so unbearably sad", "heart just arches",...
# 26  "if I am dead", "existing as this human that d...
# 27                                                NaN
# 28  "biggest anxiety attack", "convinced... i wa d...
# 29                                                NaN
# 30                                                NaN
# 31  "wish i was better off dead", "I think of endi...
# 32                                                NaN
# 33  "I cannot get my life back", "there is no poin...
# 34  "very much depressed", "hurts so much", "Every...
# 35                                                NaN
# 36  "i am going to kill myself tonight", "my life ...
# 37  "admitting that I need help", "having thoughts...
# 38                                                NaN
# 39  "it just... turned", "not being able to wear c...
# 40  "Who needs to die? Me", "I wish I could just d...
# 41  "I just wanna die", "I still wanna die", "over...
# 42                                                NaN
# 43  "tempted to go to my peace place and go sit on...
# 44  "feel like I am trapped but do not want to esc...
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49  "severe depression", "barely have the desire t...
# 50                                                NaN
# 51  "feel like i m not good enough for anyone", "i...
# 52  "shitty lonely times", "struggle with psychoti...
# 53                                                NaN
# 54  "realize damn I am not okay", "Years of compar...
# 55  "do not necessarily fear death", "affaid I wou...
# 56  "spending these last few day in a hedonistic f...
# 57                                                NaN
# 58  "suicidal feelings", "parent making you feel l...
# 59                                                NaN
#
#                                                 notes
# 0                                                 NaN
# 1                                                 NaN
# 2   It doesn't actually have a clear meaning, but ...
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 57                                                NaN
# 58                                                NaN
# 59                                                NaN

# %%
for i in range(len(manual_df)):
    if (
        manual_df.loc[i, "manual_label (code)"] != shuffled_df.loc[i, "status"]
        and manual_df.loc[i, "statement"].strip().lower()
        == shuffled_df.loc[i, "statement"].strip().lower()
    ):
        print(
            f"Mismatch at Row {i + 2}: Our code = {manual_df.loc[i, 'manual_label (code)']}, Original status = {shuffled_df.loc[i, 'status']}"
        )
# Out:
# Mismatch at Row 7: Our code = Depression, Original status = Suicidal
# Mismatch at Row 17: Our code = Suicidal, Original status = Depression
# Mismatch at Row 23: Our code = Suicidal, Original status = Depression
# Mismatch at Row 27: Our code = Depression, Original status = Suicidal
# Mismatch at Row 28: Our code = Suicidal, Original status = Depression
# Mismatch at Row 33: Our code = Suicidal, Original status = Depression
# Mismatch at Row 39: Our code = Depression, Original status = Suicidal
# Mismatch at Row 41: Our code = Depression, Original status = Normal
# Mismatch at Row 43: Our code = Suicidal, Original status = Depression
# Mismatch at Row 46: Our code = Depression, Original status = Suicidal
# Mismatch at Row 50: Our code = Normal, Original status = Suicidal
# Mismatch at Row 54: Our code = Depression, Original status = Suicidal
# Mismatch at Row 58: Our code = Suicidal, Original status = Depression
